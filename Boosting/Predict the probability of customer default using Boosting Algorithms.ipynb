# %% [markdown]
# ## Problem Statement - Predict the probability of customer default using Boosting Algorithms

# %% [markdown]
# The main aim of this project is to predict the probabily whether a customer will default in the future given his record present in the dataset. We will be using predict_proba to determine the delinquency probabilities of the customer.

# %% [markdown]
# ### What is Ensemble Machine Learning?

# %% [markdown]
# An ensemble is a composite model, combines a series of low performing classifiers with the aim of creating an improved classifier. Here, individual classifier vote and final prediction label returned that performs majority voting.
#
# - Ensembles offer more accuracy than individual or base classifier.
# - Ensemble methods can parallelize by allocating each base learner to different-different machines.
# - Also Ensemble learning methods are meta-algorithms that combine several machine learning methods into a single predictive model to increase performance.
# - Ensemble methods can decrease variance using bagging approach, bias using a boosting approach, or improve predictions using stacking approach.
#
# Three types of Ensemble Learning Methods are :
# - Boosting
# - Bagging
# - Stacking

# %% [markdown]
# ### What is Boosting?

# %% [markdown]
# Boosting are a set of the low accurate classifiers combined to create a highly accurate classifier. Low accuracy classifier (or weak classifier) offers the accuracy better than the flipping of a coin. Highly accurate classifier( or strong classifier) offer error rate close to 0. Boosting algorithms can track the model who failed the accurate prediction. Boosting algorithms are less affected by the overfitting problem.

# %% [markdown]
# ### 1. AdaBoost Classifier

# %% [markdown]
# AdaBoost is an iterative ensemble method. AdaBoost classifier builds a strong classifier by combining multiple poorly performing classifiers so that you will get high accuracy strong classifier. The basic concept behind Adaboost is to set the weights of classifiers and training the data sample in each iteration such that it ensures the accurate predictions of unusual observations. Any machine learning algorithm can be used as base classifier if it accepts weights on the training set. Adaboost should meet two conditions:
#
# - The classifier should be trained interactively on various weighed training examples.
# - In each iteration, it tries to provide an excellent fit for these examples by minimizing training error.

# %% [markdown]
# #### How does the AdaBoost algorithm work?

# %% [markdown]
# It works in the following steps:
#
# - Initially, Adaboost selects a training subset randomly.
#
# - It iteratively trains the AdaBoost machine learning model by selecting the training set based on the accurate prediction of the last training.
#
# - It assigns the higher weight to wrong classified observations so that in the next iteration these observations will get the high probability for classification.
#
# - Also, It assigns the weight to the trained classifier in each iteration according to the accuracy of the classifier. The more accurate classifier will get high weight.
#
# - The process will iterate until the complete training data fits without any error or until reached to the specified maximum number of estimators.
#
# - To classify, perform a "vote" across all of the learning algorithms you built.

# %% [markdown]
# ### 2. XGBoost Classifier

# %% [markdown]
# XGBOOST stands for Extreme Gradient Boosting. This algorithm is an improved version of the Gradient Boosting Algorithm. The base algorithm is Gradient Boosting Decision Tree Algorithm. Its powerful predictive power and easy to implement approach.
#
# key points of the algorithm are as follows:
#
# - It does not build the full tree structure but builds it greedily.
# - In Gradient Boosting, negative gradients are taken into account to optimize the loss function but here Taylor’s expansion is taken into account.
# - The regularization term penalizes from building complex tree models.

# %% [markdown]
# #### How does the XGBoost algorithm work?

# %% [markdown]
# Gradient boosting
# Boosting is an ensemble method, meaning it’s a way of combining predictions from several models into one. It does that by taking each predictor sequentially and modelling it based on its predecessor’s error (giving more weight to predictors that perform better):
#
# - Fit a first model using the original data
# - Fit a second model using the residuals of the first model
# - Create a third model using the sum of models 1 and 2
#
# Gradient boosting is a specific type of boosting, called like that because it minimises the loss function using a gradient descent algorithm. XGBoost  is a gradient boosting algorithm that uses decision trees as its “weak” predictors. Beyond that, its implementation was specifically engineered for optimal performance and speed.
#
# Historically, XGBoost has performed quite well for structured, tabular data. If you are dealing with non-structured data such as images, neural networks are usually a better option.

# %% [markdown]
# ### 3. LightGBM Classifier

# %% [markdown]
# Light GBM is a gradient boosting framework that uses tree based learning algorithm.
#
# Light GBM grows tree vertically while other algorithm grows trees horizontally meaning that Light GBM grows tree leaf-wise while other algorithm grows level-wise. It will choose the leaf with max delta loss to grow. When growing the same leaf, Leaf-wise algorithm can reduce more loss than a level-wise algorithm.
#
# Light GBM is prefixed as ‘Light’ because of its high speed. Light GBM can handle the large size of data and takes lower memory to run. Another reason of why Light GBM is popular is because it focuses on accuracy of results. LGBM also supports GPU learning and thus data scientists are widely using LGBM for data science application development.
#
# It is not advisable to use LGBM on small datasets. Light GBM is sensitive to overfitting and can easily overfit small data. Their is no threshold on the number of rows but my experience suggests me to use it only for data with 10,000+ rows.

# %% [markdown]
# #### How does the LightGBM algorithm work?

# %% [markdown]
# Most decision tree learning algorithms grow tree by level (depth)-wise.
#
# If we grow the full tree, best-first (leaf-wise) and depth-first (level-wise) will result in the same tree. The difference is in the order in which the tree is expanded. Since we don't normally grow trees to their full depth, order matters.
#
# Application of early stopping criteria and pruning methods can result in very different trees. Because leaf-wise chooses splits based on their contribution to the global loss and not just the loss along a particular branch, it often (not always) will learn lower-error trees "faster" than level-wise.
#
# For a small number of nodes, leaf-wise will probably out-perform level-wise. As we add more nodes, without stopping or pruning they will converge to the same performance because they will literally build the same tree eventually.

# %% [markdown]
# ### 4. CatBoost Classifier

# %% [markdown]
# CatBoost is an open source algorithm based on gradient boosted decision trees. It supports numerical, categorical and text features. “CatBoost” name comes from two words - “Category” and “Boosting”.
#
# It works well with multiple categories of data, such as audio, text, image including historical data.
# “Boost” comes from gradient boosting machine learning algorithm as this library is based on gradient boosting library. Gradient boosting is a powerful machine learning algorithm that is widely applied to multiple types of business challenges like fraud detection, recommendation items, forecasting and it performs well also. It can also return very good results with relatively less data, unlike DL models that need to learn from a massive amount of data.
# It is in open-source and can be used by anyone.
#
# It can work with diverse data types to help solve a wide range of problems (described later) that businesses face today.
# It is developed by Yandex researchers and engineers, and is used for search, recommendation systems, personal assistant, self-driving cars, weather prediction and many other tasks. Also, it provides best-in-class accuracy.
#
# It yields state-of-the-art results without extensive data training typically required by other machine learning methods, and
# Provides powerful out-of-the-box support for the more descriptive data formats that accompany many business problems.

# %% [markdown]
# #### How does the CatBoost algorithm work?

# %% [markdown]
# CatBoost is based on gradient boosted decision trees. During training, a set of decision trees is built consecutively. Each successive tree is built with reduced loss compared to the previous trees. The number of trees is controlled by the starting parameters. To prevent overfitting, use the overfitting detector. When it is triggered, trees stop being built.
#
# Building stages for a single tree:
#
# - Preliminary calculation of splits.
# - Transforming categorical features to numerical features.
# - Transforming text features to numerical features.
# - Choosing the tree structure. This stage is affected by the set Bootstrap options.
# - Calculating values in leaves.

# %% [markdown]
# ### Perform Boosting Algorithms

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# ### Loading Dataset

# %%
train = pd.read_csv('cs-training.csv',index_col=0)
test = pd.read_csv('cs-test.csv',index_col=0)
test.head(2)
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1               1.0                              0.885519   43
# 2               0.0                              0.463295   57
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                                     0   0.177513         5700.0
# 2                                     0   0.527237         9141.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                                4                        0
# 2                               15                        0
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                             0                                     0
# 2                             4                                     0
#
#    NumberOfDependents
# 1                 0.0
# 2                 2.0

# %%
#add an indicator column for training data
train['ind']='train'
train.head(2)
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                 1                              0.766127   45
# 2                 0                              0.957151   40
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                                     2   0.802982         9120.0
# 2                                     0   0.121876         2600.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                               13                        0
# 2                                4                        0
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                             6                                     0
# 2                             0                                     0
#
#    NumberOfDependents    ind
# 1                 2.0  train
# 2                 1.0  train

# %%
#add an indicator column for testing data
test['ind']='test'
test.head(2)
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1               1.0                              0.885519   43
# 2               0.0                              0.463295   57
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                                     0   0.177513         5700.0
# 2                                     0   0.527237         9141.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                                4                        0
# 2                               15                        0
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                             0                                     0
# 2                             4                                     0
#
#    NumberOfDependents   ind
# 1                 0.0  test
# 2                 2.0  test

# %%
#merge train and test to create single dataset for pre-processing
df = pd.concat([train,test])

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#check shape of train
train.shape
# Out:
# (150000, 12)

# %%
test.shape
# Out:
# (101503, 12)

# %%
df.shape
# Out:
# (251503, 12)

# %% [markdown]
# In the combined dataset there are 251503 rows and 13 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 251503 entries, 1 to 101503
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   SeriousDlqin2yrs                      251478 non-null  float64
#  1   RevolvingUtilizationOfUnsecuredLines  251503 non-null  float64
#  2   age                                   251503 non-null  int64
#  3   NumberOfTime30-59DaysPastDueNotWorse  251503 non-null  int64
#  4   DebtRatio                             251503 non-null  float64
#  5   MonthlyIncome                         201669 non-null  float64
#  6   NumberOfOpenCreditLinesAndLoans       251503 non-null  int64
#  7   NumberOfTimes90DaysLate               251503 non-null  int64
#  8   NumberRealEstateLoansOrLines          251503 non-null  int64
#  9   NumberOfTime60-89DaysPastDueNotWorse  251503 non-null  int64
# ...

# %% [markdown]
# All the variables are numerical ie int and float.
#
# Only ind column is of object catgory, which was added by us to keep the train and test data different.
#
# SeriousDlqin2yrs is the target and the rest of them except the ind are the predictors.

# %%
df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     251478.000000                         251503.000000  251503.000000
# mean           0.066781                              5.750415      52.339694
# std            0.249643                            229.633980      14.775120
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.029977      41.000000
# 50%            0.000000                              0.153575      52.000000
# 75%            0.000000                              0.561293      63.000000
# max            1.000000                          50708.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         251503.000000  251503.000000   2.016690e+05
# mean                               0.434245     349.562468   6.744818e+03
# ...

# %% [markdown]
# #### Handling missing values

# %%
#check null values
df.isnull().sum()
# Out:
# SeriousDlqin2yrs                           25
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           49834
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       6550
# ind                                         0
# dtype: int64

# %%
#visualize missing values
sns.heatmap(df.isnull(),yticklabels = False, cbar=False, cmap='viridis')
plt.show()

# %%
#find the cols with missing values
predictors_with_missing_vals = [col for col in df.columns if df[col].isnull().sum() > 1]
predictors_with_missing_vals
# Out:
# ['SeriousDlqin2yrs', 'MonthlyIncome', 'NumberOfDependents']

# %% [markdown]
# SeriousDlqin2yrs is the target variable. Hence we can drop the rows for missing values for SeriousDlqin2yrs.
#
# For 'MonthlyIncome', 'NumberOfDependents', we will apply imputation.

# %%
#for the target - drop the rows having missing values
df = df.dropna(subset=['SeriousDlqin2yrs'])
df.isnull().sum()
# Out:
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           49827
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       6548
# ind                                         0
# dtype: int64

# %%
df1 = df.copy()
df1.drop(['ind'],axis=1,inplace=True)
df1
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                    1.0                              0.766127   45
# 2                    0.0                              0.957151   40
# 3                    0.0                              0.658180   38
# 4                    0.0                              0.233810   30
# 5                    0.0                              0.907239   49
# ...                  ...                                   ...  ...
# 101499               1.0                              0.282653   24
# 101500               0.0                              0.922156   36
# 101501               0.0                              0.081596   70
# 101502               0.0                              0.335457   56
# 101503               0.0                              0.441842   29
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 1                                          2     0.802982         9120.0
# ...

# %%
#handle the remaining cols - 'MonthlyIncome', 'NumberOfDependents'
#from sklearn.preprocessing import Imputer
#Fit the numerical data to Imputer
from sklearn.impute import SimpleImputer


imputer = SimpleImputer(strategy="median")
imputer.fit(df1)

X = imputer.transform(df1)
df_tr = pd.DataFrame(X, columns=df1.columns, 
                    index=df.index)

df_tr.head(2)
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines   age  \
# 1               1.0                              0.766127  45.0
# 2               0.0                              0.957151  40.0
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                                   2.0   0.802982         9120.0
# 2                                   0.0   0.121876         2600.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                             13.0                      0.0
# 2                              4.0                      0.0
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                           6.0                                   0.0
# 2                           0.0                                   0.0
#
#    NumberOfDependents
# 1                 2.0
# 2                 1.0

# %%
df_tr.isnull().sum()
# Out:
# SeriousDlqin2yrs                        0
# RevolvingUtilizationOfUnsecuredLines    0
# age                                     0
# NumberOfTime30-59DaysPastDueNotWorse    0
# DebtRatio                               0
# MonthlyIncome                           0
# NumberOfOpenCreditLinesAndLoans         0
# NumberOfTimes90DaysLate                 0
# NumberRealEstateLoansOrLines            0
# NumberOfTime60-89DaysPastDueNotWorse    0
# NumberOfDependents                      0
# dtype: int64

# %%
df_final  = df_tr
df_final['ind']= df['ind']
df_final
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines   age  \
# 1                    1.0                              0.766127  45.0
# 2                    0.0                              0.957151  40.0
# 3                    0.0                              0.658180  38.0
# 4                    0.0                              0.233810  30.0
# 5                    0.0                              0.907239  49.0
# ...                  ...                                   ...   ...
# 101499               1.0                              0.282653  24.0
# 101500               0.0                              0.922156  36.0
# 101501               0.0                              0.081596  70.0
# 101502               0.0                              0.335457  56.0
# 101503               0.0                              0.441842  29.0
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# ...

# %% [markdown]
# #### Data distribution

# %%
#check for balanced vs imbalanced data in the target variable
df_final[['SeriousDlqin2yrs']].value_counts().plot(kind='bar',title = 'Count - SeriousDlqin2yrs')
# Out:
# <AxesSubplot:title={'center':'Count - SeriousDlqin2yrs'}, xlabel='SeriousDlqin2yrs'>

# %%
#draw a piechart 
ax = df_final['SeriousDlqin2yrs'].value_counts().plot(kind='pie',autopct='%.4f', shadow=True)
ax.set_title("Distribution of Delinquencies")
plt.show()

# %% [markdown]
# The ratio of negative to positive delinquency values are found to be 93.3% to 6.7%, which is approximately a ratio of 14:1. Therefore, our dataset is highly imbalanced.

# %%
num = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

num_df = df_final.select_dtypes(include=num)

num_cols = num_df.columns.difference(['SeriousDlqin2yrs'])

num_cols
# Out:
# Index(['DebtRatio', 'MonthlyIncome', 'NumberOfDependents',
#        'NumberOfOpenCreditLinesAndLoans',
#        'NumberOfTime30-59DaysPastDueNotWorse',
#        'NumberOfTime60-89DaysPastDueNotWorse', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'RevolvingUtilizationOfUnsecuredLines',
#        'age'],
#       dtype='object')

# %%
#check outliers by creating box plots for all the numeric predictors
for c in num_cols:
    ax = df_final.boxplot([c],color ='blue')
    plt.show()

# %% [markdown]
# There are outliers that need to be removed.

# %%
# distribution plot for each predictor 
for c in num_cols:
    sns.distplot(df_final[c], kde=True, color='blue',bins=10)
    plt.show()

# %% [markdown]
# Distribution of all the predictors are left-skewed. We will apply for box-cox transformation to handle the skewness. Only Age is somewhat close to a normal distribution.

# %%
#the kernel density estimate is used in density plots to show the probability density function of the variable. A continuous curve, which is the kernel is drawn to generate a smooth density estimation 
#for the whole data.
# distribution plot for each predictor 
for c in num_cols:
    df_final[c].plot(kind='density')
    plt.xlabel(c)
    plt.show()

# %% [markdown]
# Highest number of values for almost all predictors are maximum for 0 value, Except NumberOfOpenCreditLinesAndLoans(maximum values  betweem 0-25) and Age(0-50).

# %%
#bivariate analysis
for c in num_cols:
    df_final.plot.scatter(x='SeriousDlqin2yrs', y=c)
    plt.show()

# %% [markdown]
# This shows the distribution of the predictors vs the target variable.

# %%
#bivariate analysis
for c in num_cols:
    df_final.plot.hexbin(x='SeriousDlqin2yrs', y=c,gridsize=15)
    plt.show()

# %% [markdown]
# Like the Density plot, this also shows the concentration of the predictor variables.

# %%
#multi-variate analysis
#sns.pairplot(df_final,size=3)
#plt.show()

# %% [markdown]
# #### Outliers handling

# %%
df_final.shape
# Out:
# (251478, 12)

# %%
# use z-score to remove outliers
for c in num_cols:
    upper_limit = df_final[c].mean() + 3*df_final[c].std()
    lower_limit = df_final[c].mean() - 3*df_final[c].std()
    df_final[c] = np.where(
        df_final[c]>upper_limit,
        upper_limit,
        np.where(
            df_final[c]<lower_limit,
            lower_limit,
            df_final[c]
        )
    )

# %% [markdown]
# #### Correlation Analysis

# %%
#correlation analysis 
cor = df_final.corr()
cor
# Out:
#                                       SeriousDlqin2yrs  \
# SeriousDlqin2yrs                              1.000000
# RevolvingUtilizationOfUnsecuredLines          0.000987
# age                                          -0.066688
# NumberOfTime30-59DaysPastDueNotWorse          0.154360
# DebtRatio                                    -0.009517
# MonthlyIncome                                -0.023518
# NumberOfOpenCreditLinesAndLoans              -0.018285
# NumberOfTimes90DaysLate                       0.156545
# NumberRealEstateLoansOrLines                 -0.010287
# NumberOfTime60-89DaysPastDueNotWorse          0.119943
# NumberOfDependents                            0.029047
#
#                                       RevolvingUtilizationOfUnsecuredLines  \
# SeriousDlqin2yrs                                                  0.000987
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.010636
# ...

# %%
sns.heatmap(cor,cmap=sns.diverging_palette(150, 275, s=80, l=55, n=9),  center = 0)
plt.title("Correlation Matrix (HeatMap)", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix (HeatMap)')

# %% [markdown]
# We can see the most correlated values to SeriousDlqin2yrs are NumberOfTime30-59DaysPastDueNotWorse , NumberOfTime60-89DaysPastDueNotWorse and NumberOfTimes90DaysLate.

# %% [markdown]
# #### Skewness

# %%
skewed_cols = df_final[num_cols].skew().sort_values(ascending=False)
df_skewed = pd.DataFrame({'Skew':skewed_cols})
df_skewed
# Out:
#                                            Skew
# RevolvingUtilizationOfUnsecuredLines  27.014902
# NumberOfTime60-89DaysPastDueNotWorse  15.763994
# NumberOfTimes90DaysLate               12.601173
# NumberOfTime30-59DaysPastDueNotWorse   7.791805
# MonthlyIncome                          5.694837
# DebtRatio                              3.618040
# NumberOfDependents                     1.369289
# NumberRealEstateLoansOrLines           0.961375
# NumberOfOpenCreditLinesAndLoans        0.843500
# age                                    0.187142

# %%
df_skewed_final = df_skewed[abs(df_skewed )>0.5].dropna()
df_skewed_final.index
# Out:
# Index(['RevolvingUtilizationOfUnsecuredLines',
#        'NumberOfTime60-89DaysPastDueNotWorse', 'NumberOfTimes90DaysLate',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'MonthlyIncome', 'DebtRatio',
#        'NumberOfDependents', 'NumberRealEstateLoansOrLines',
#        'NumberOfOpenCreditLinesAndLoans'],
#       dtype='object')

# %%
from scipy import stats, special
for i in df_skewed_final.index:
    df_final[i] = special.boxcox1p(df_final[i],0.15) #lambda = 0.15
    
df_final.head(2)
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines   age  \
# 1               1.0                              0.593758  45.0
# 2               0.0                              0.706472  40.0
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                              1.194318   0.616285      19.510046
# 2                              0.000000   0.116000      15.019350
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                         3.237728                      0.0
# 2                         1.820334                      0.0
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                      1.914581                                   0.0
# 2                      0.000000                                   0.0
#
#    NumberOfDependents    ind
# 1            1.194318  train
# 2            0.730463  train

# %%
# distribution plot for each predictor 
for c in num_cols:
    sns.distplot(df_final[c], kde=True, color='blue',bins=10)
    plt.show()

# %%
#check the skewness again
skewed_cols = df_final[num_cols].skew().sort_values(ascending=False)
df_skewed = pd.DataFrame({'Skew':skewed_cols})
df_skewed
# Out:
#                                            Skew
# RevolvingUtilizationOfUnsecuredLines  15.506790
# NumberOfTime60-89DaysPastDueNotWorse   7.235185
# NumberOfTimes90DaysLate                6.278402
# NumberOfTime30-59DaysPastDueNotWorse   3.087250
# DebtRatio                              1.922855
# NumberOfDependents                     0.902372
# NumberRealEstateLoansOrLines           0.217727
# age                                    0.187142
# NumberOfOpenCreditLinesAndLoans       -0.475464
# MonthlyIncome                         -2.413125

# %% [markdown]
# The skewness has reduced.

# %% [markdown]
# #### Feature Engineering

# %%
#Add relevant New Features as needed
df_final['MonthlyIncomePerPerson'] = df_final['MonthlyIncome']/(df_final['NumberOfDependents']+1)
df_final['MonthlyIncomePerPerson'].fillna(0, inplace=True)

df_final['MonthlyDebt'] = df_final['MonthlyIncome']*df_final['DebtRatio']
df_final['MonthlyDebt'].fillna(df_final['DebtRatio'],inplace=True)
df_final['MonthlyDebt'] = np.where(df_final['MonthlyDebt']==0, df_final['DebtRatio'],df_final['MonthlyDebt'])

df_final['isRetired'] = np.where((df_final['age'] > 65), 1, 0)

df_final['RevolvingLines'] = df_final['NumberOfOpenCreditLinesAndLoans']-df_final['NumberRealEstateLoansOrLines']

df_final['hasRevolvingLines']=np.where((df_final['RevolvingLines']>0),1,0)

df_final['hasMultipleRealEstates'] = np.where((df_final['NumberRealEstateLoansOrLines']>=2),1,0)

df_final['incomeDivByThousand'] = df_final['MonthlyIncome']/1000

# %%
df_final.shape
# Out:
# (251478, 19)

# %% [markdown]
# ### Split the data set into train and test

# %%
#split Train and Test Data
df_train = df_final[df_final['ind']=='train'] 
df_train
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines   age  \
# 1                    1.0                              0.593758  45.0
# 2                    0.0                              0.706472  40.0
# 3                    0.0                              0.525397  38.0
# 4                    0.0                              0.213453  30.0
# 5                    0.0                              0.677957  49.0
# ...                  ...                                   ...   ...
# 149996               0.0                              0.039988  74.0
# 149997               0.0                              0.267391  44.0
# 149998               0.0                              0.223643  58.0
# 149999               0.0                              0.000000  30.0
# 150000               0.0                              0.644631  64.0
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# ...

# %%
X_train = df_train[df_train.columns.difference(['SeriousDlqin2yrs','ind'])]
y_train = df_train['SeriousDlqin2yrs']

# %%
df_test = df_final[df_final['ind']=='test'] 
df_test
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines   age  \
# 1                    1.0                              0.665349  43.0
# 2                    0.0                              0.391770  57.0
# 3                    0.0                              0.042500  59.0
# 4                    0.0                              0.251737  38.0
# 5                    0.0                              0.730463  27.0
# ...                  ...                                   ...   ...
# 101499               1.0                              0.253637  24.0
# 101500               0.0                              0.686544  36.0
# 101501               0.0                              0.078901  70.0
# 101502               0.0                              0.295641  56.0
# 101503               0.0                              0.376150  29.0
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# ...

# %%
X_test = df_test[df_test.columns.difference(['SeriousDlqin2yrs','ind'])]
y_test = df_test['SeriousDlqin2yrs']

# %%
print(X_train.shape, y_train.shape)
# Out:
# (150000, 17) (150000,)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (101478, 17) (101478,)

# %% [markdown]
# ### Imbalanced Data Handling
#
# SMOTE or Synthetic Minority Oversampling Technique is an oversampling technique. It aims to balance class distribution by randomly increasing minority class examples by replicating them.
#
# SMOTE synthesizes new minority instances between existing minority instances. It generates the virtual training records by linear interpolation for the minority class. These synthetic training records are generated by randomly selecting one or more of the k-nearest neighbors for each example in the minority class. After the oversampling process, the data is reconstructed and several classification models can be applied for the processed data.

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))
 
# import SMOTE module from imblearn library
# pip install imblearn (if you don't have imblearn in your system)
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)
 
print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))
 
print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# Out:
# Before OverSampling, counts of label '1': 10026
# Before OverSampling, counts of label '0': 139974
#
# After OverSampling, the shape of train_X: (279948, 17)
# After OverSampling, the shape of train_y: (279948,)
#
# After OverSampling, counts of label '1': 139974
# After OverSampling, counts of label '0': 139974

# %% [markdown]
# ### Model Building

# %% [markdown]
# #### 1.Adaboost Model

# %%
#create basic AdaBoost model 
#base_estimator: Weak learner used to train the model.It uses DecisionTreeClassifier as default weak learner for training purpose. You can also specify different machine learning algorithms.
#n_estimators: Number of weak learners to train iteratively.
#learning_rate: It contributes to the weights of weak learners. It uses 1 as a default value.
from sklearn.ensemble import AdaBoostClassifier
model_ada = AdaBoostClassifier(n_estimators=50, learning_rate=1)

# %%
#train Adaboost Classifer
model_ada.fit(X_train_res, y_train_res)
# Out:
# AdaBoostClassifier(learning_rate=1)

# %%
#predict the response for test dataset
y_pred_res = model_ada.predict(X_test)

# %% [markdown]
# #### Evaluate model

# %%
from sklearn import metrics
# Model Accuracy, how often is the classifier correct
metrics.accuracy_score(y_test, y_pred_res)
# Out:
# 0.8403693411379807

# %% [markdown]
# #### Hyperparameter tuning

# %%
#some of the hyperparameters that should be considered for tuning for the AdaBoost ensemble and their effect on model performance.
#two hyperparameters - number of estimators (n_estimators-how many trees are developed) and the learning rate(how each tree contributes to the overall results)
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

#k-fold CV - train the model k-times and also test it k-times
crossvalidation=KFold(n_splits=10)
grid_param={'n_estimators':[5, 10,20,30,40, 50,100],'learning_rate':[.001,0.01,.1]}
grid_param
# Out:
# {'n_estimators': [5, 10, 20, 30, 40, 50, 100],
#  'learning_rate': [0.001, 0.01, 0.1]}

# %%
#estimator: estimator object being used
#param_grid: dictionary that contains all of the parameters to try
#scoring: evaluation metric to use when ranking results
#cv: cross-validation, the number of cv folds for each combination of parameters
ada_cv=GridSearchCV(estimator=model_ada,param_grid=grid_param,scoring='accuracy',n_jobs=1,cv=5)
#ada_cv=GridSearchCV(estimator=model_ada,param_grid=grid_param,scoring='accuracy',n_jobs=1,cv=crossvalidation)
ada_cv
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(learning_rate=1), n_jobs=1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'n_estimators': [5, 10, 20, 30, 40, 50, 100]},
#              scoring='accuracy')

# %%
#fit the Cross validated ada model
ada_cv.fit(X_train_res,y_train_res)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(learning_rate=1), n_jobs=1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'n_estimators': [5, 10, 20, 30, 40, 50, 100]},
#              scoring='accuracy')

# %%
#find the best parameters
ada_cv.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}

# %%
#find best model score
ada_cv.best_score_
# Out:
# 0.8369626321395109

# %%
score = {}
score['adaboost']=  (np.mean(ada_cv.best_score_) * 100).round(3)
score
# Out:
# {'adaboost': 83.696}

# %% [markdown]
# The exhaustive search identified the best parameters for our Adaboost Classifier to be learning_rate=0.1 and n_estimators=50. This combination of parameters produced an accuracy score of 0.8369626321395109.

# %% [markdown]
# ##### Pros and Cons  of Adaboost
#
# 1) Pros
# - AdaBoost is easy to implement.
# - It iteratively corrects the mistakes of the weak classifier and improves accuracy by combining weak learners. You can use many base classifiers with AdaBoost.
# - AdaBoost is not prone to overfitting. This can be found out via experiment results, but there is no concrete reason available.
#
# 2) Cons
# - AdaBoost is sensitive to noise data.
# - It is highly affected by outliers because it tries to fit each point perfectly. -
# - AdaBoost is slower compared to XGBoost.

# %% [markdown]
# #### 2.XGBoost Model

# %% [markdown]
# The overall parameters have been divided into 3 categories by XGBoost authors:
#
# - General Parameters: Guide the overall functioning
#
#    - booster [default=gbtree]:type of model to run at each iteration, gbtree(tree-based) or gblinear(linear)
#
#    - silent [default=0]:type of message printing, 1(no running messages are printed) or 0(detailed messages are printed)
#
#    - nthread [default to maximum number of threads available if not set]: number of cores on which algorithm will be run
#
# - Booster Parameters: Guide the individual booster (tree/re. gression) at each step
#
#     - eta [default=3] - Makes the model more robust by shrinking the weights on each step, Typical final values to be used: 0.01-0.2
#
#     - min_child_weight [default=1] - the minimum sum of weights of all observations required in a child. Used to control over-fitting
#
#     - max_depth [default=6] - maximum depth of a tree. Typical values: 3-10. Used to control over-fitting.
#
#     - max_leaf_nodes - maximum number of terminal nodes or leaves in a tree
#
#     - gamma [default=0] - A node is split only when the resulting split gives a positive reduction in the loss function. Gamma specifies the minimum loss reduction required to make a split.
#
#     - max_delta_step [default=0] - In maximum delta step we allow each tree’s weight estimation to be. If the value is set to 0, it means there is no constraint. If it is set to a positive value, it can help making the update step more conservative.
#
#     - subsample [default=1] - Denotes the fraction of observations to be randomly samples for each tree. Typical values: 0.5-1
#
#     - colsample_bylevel [default=1] - Denotes the subsample ratio of columns for each split, in each level.
#
#     - lambda [default=1] - handle the L2 regularization part
#
#     - alpha [default=0] - L1 regularization term on weight
#
#     - scale_pos_weight [default=1] - A value greater than 0 should be used in case of high class imbalance as it helps in faster convergence.
#
# - Learning Task Parameters: Guide the optimization performed
#
#    - objective [default=reg:linear] - defines the loss function to be minimized. Typlical values are binary:logistic, multi:softmax
#
#    - eval_metric - metric to be used for validation data. Typical values are rmse,mae
#
#    - seed [default=0] - random number seed.

# %%
from xgboost import XGBClassifier

#create the basic XGBoost model
model_xgb=XGBClassifier(max_depth=7,
                        learning_rate=0.05,
                        eta=1,
                        objective='binary:logistic',
                        eval_metric='error') 

model_xgb
# Out:
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, eta=1,
#               eval_metric='error', gamma=None, gpu_id=None,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.05, max_delta_step=None, max_depth=7,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None)

# %%
#fit the model
model_xgb.fit(X_train_res, y_train_res)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eta=1,
#               eval_metric='error', gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#               max_depth=7, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=12,
#               num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=1, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
# make the predictions 
y_pred_xgb_res=model_xgb.predict(X_test)

# %% [markdown]
# #### Evaluate Model

# %%
#model Accuracy, how often is the classifier correct
metrics.accuracy_score(y_test, y_pred_xgb_res)
# Out:
# 0.8910798399653127

# %% [markdown]
# #### Hyperparameter Tuning

# %%
grid_params_xgb = { 'max_depth': [3,4,5],
                'learning_rate': [0.01, 0.05, 0.1],
                'n_estimators': [5,10,20],
               # 'subsample':[1,2,3,4,5],
               # 'colsample_bytree':[6,7,8,9,10],
               # 'min_child_weight':range(1,6,2),
               # 'gamma':[0,1,2,3,4,5],
               #'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100]
              }

xgb_cv = GridSearchCV(estimator=model_xgb, 
                   param_grid=grid_params_xgb,
                   scoring='accuracy', 
                   verbose=1, cv=5)

xgb_cv.fit(X_train_res,y_train_res)
xgb_cv
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, eta=1,
#                                      eval_metric='error', gamma=0, gpu_id=-1,
#                                      importance_type='gain',
#                                      interaction_constraints='',
#                                      learning_rate=0.05, max_delta_step=0,
#                                      max_depth=7, min_child_weight=1,
#                                      missing=nan, monotone_constraints='()',
#                                      n_estimators=100, n_jobs=12,
#                                      num_parallel_tree=1, random_state=0,
#                                      reg_alpha=0, reg_lambda=1,
# ...

# %%
#find the best parameters
xgb_cv.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 20}

# %%
xgb_cv.best_score_
# Out:
# 0.8638748170148531

# %%
score['xgboost']=  (np.mean(xgb_cv.best_score_) * 100).round(3)
score
# Out:
# {'adaboost': 83.696, 'xgboost': 86.387}

# %% [markdown]
# The exhaustive search identified the best parameters for our xgboost Classifier to be learning_rate=0.1,max_depth=5 and n_estimators=20. This combination of parameters produced an accuracy score of 0.8638748170148531.

# %% [markdown]
# #### Pros and Cons of XGBoost

# %% [markdown]
# 1)Pros
# - Less feature engineering required (No need for scaling, normalizing data, can also handle missing values well)
# - Feature importance can be found out(it output importance of each feature, can be used for feature selection)
# - Fast to interpret
# - Outliers have minimal impact.
# - Handles large sized datasets well.
# - Good Execution speed
# - Good model performance (wins most of the Kaggle competitions)
# - Less prone to overfitting
#
# 2)Cons
# - Difficult interpretation , visualization tough
# - Overfitting possible if parameters not tuned properly.
# - Harder to tune as there are too many hyperparameters.

# %% [markdown]
# #### 3. LightGBM Model

# %% [markdown]
# The overall parameters have been divided into 3 categories by LightGBM authors:
#
# -Control Parameters: Guide the overall functioning
#
# - max_depth : It describes the maximum depth of tree. This parameter is used to handle model overfitting. If you feel that   your model is overfitted, you should to lower max_depth.
#
# - min_data_in_leaf : It is the minimum number of the records a leaf may have. The default value is 20, optimum value. It is also used to deal with overfitting.
#
# - feature_fraction: Used when your boosting is random forest. 0.8 feature fraction means LightGBM will select 80% of parameters randomly in each iteration for building trees.
#
# - bagging_fraction : specifies the fraction of data to be used for each iteration and is generally used to speed up the training and avoid overfitting.
#
# - early_stopping_round : This parameter can help you speed up your analysis. Model will stop training if one metric of one validation data doesn’t improve in last early_stopping_round rounds. This will reduce excessive iterations.
#
# - lambda : lambda specifies regularization. Typical value ranges from 0 to 1.
#
# - min_gain_to_split : This parameter will describe the minimum gain to make a split. It can used to control number of useful splits in tree.
#
# - max_cat_group : When the number of category is large, finding the split point on it is easily over-fitting. So LightGBM merges them into ‘max_cat_group’ groups, and finds the split points on the group boundaries, default:64.
#
# -Core Parameters
#
# - Task : It specifies the task you want to perform on data. It may be either train or predict.
#
# - application : This is the most important parameter and specifies the application of your model, whether it is a regression problem or classification problem. LightGBM will by default consider model as a regression model.
#
# - regression : for regression
#
# - binary : for binary classification
#
# - multiclass : for multiclass classification problem
#
# - boosting : defines the type of algorithm you want to run, default=gdbt.
#
# - gbdt : traditional Gradient Boosting Decision Tree
#
# - rf : random forest
#
# - dart : Dropouts meet Multiple Additive Regression Trees
#
# - goss : Gradient-based One-Side Sampling
#
# - num_boost_round : Number of boosting iterations, typically 100+
#
# - learning_rate : This determines the impact of each tree on the final outcome. GBM works by starting with an initial estimate which is updated using the output of each tree. The learning parameter controls the magnitude of this change in the estimates. Typical values: 0.1, 0.001, 0.003…
#
# - num_leaves : number of leaves in full tree, default: 31
#
# - device : default: cpu, can also pass gpu
#
# -Metric Parameter
#
# - metric: again one of the important parameter as it specifies loss for model building. Below are few general losses for regression and classification.
#
# - mae : mean absolute error
#
# - mse : mean squared error
#
# - binary_logloss : loss for binary classification
#
# - multi_logloss : loss for multi classification
#
# -IO Parameter
#
# - max_bin : it denotes the maximum number of bin that feature value will bucket in.
#
# - categorical_feature : It denotes the index of categorical features. If categorical_features=0,1,2 then column 0, column 1 and column 2 are categorical variables.
#
# - ignore_column : same as categorical_features just instead of considering specific columns as categorical, it will completely ignore them.
#
# - save_binary : If you are really dealing with the memory size of your data file then specify this parameter as ‘True’. Specifying parameter true will save the dataset to binary file, this binary file will speed your data reading time for the next time.

# %%
#!pip install lightgbm
import lightgbm as lgb

# %%
#create the default model 
model_lgb = lgb.LGBMClassifier(learning_rate=0.09,
                        max_depth=-5,
                        random_state=42)
model_lgb
# Out:
# LGBMClassifier(learning_rate=0.09, max_depth=-5, random_state=42)

# %%
#fit the model
model_lgb.fit(X_train_res,
       y_train_res,eval_set=[(X_test,y_test),(X_train_res,y_train_res)],
          verbose=20,eval_metric='binary_logloss')
# Out:
# [20]	training's binary_logloss: 0.293781	valid_0's binary_logloss: 0.392047
# [40]	training's binary_logloss: 0.206826	valid_0's binary_logloss: 0.349309
# [60]	training's binary_logloss: 0.163499	valid_0's binary_logloss: 0.331858
# [80]	training's binary_logloss: 0.14309	valid_0's binary_logloss: 0.321672
# [100]	training's binary_logloss: 0.134354	valid_0's binary_logloss: 0.318437
# LGBMClassifier(learning_rate=0.09, max_depth=-5, random_state=42)

# %%
# make the predictions 
y_pred_lgb_res=model_lgb.predict(X_test)

# %% [markdown]
# #### Evaluate Model

# %%
#model Accuracy, how often is the classifier correct
metrics.accuracy_score(y_test, y_pred_lgb_res)
# Out:
# 0.9015747255562782

# %%
#plotting the various feature importance, metric evaluation and the tree plot
lgb.plot_importance(model_lgb)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
lgb.plot_metric(model_lgb)
# Out:
# <AxesSubplot:title={'center':'Metric during training'}, xlabel='Iterations', ylabel='binary_logloss'>

# %% [markdown]
# The validation curve will tend to increase after it has crossed the 100th evaluation. This can be totally fixed by tuning and setting the hyperparameters of the model.

# %% [markdown]
# #### Hyperparameters Tuning

# %%
grid_params_lgb = {'num_leaves': [6, 50], 
             'min_child_samples': [10, 20, 50, 100], 
             'min_child_weight': [ 1e-1, 1, 1e1 ],
             'learning_rate': [0.01, 0.05, 0.1],
             'n_estimators': [5,10,20],
            # 'subsample': sp_uniform(loc=0.2, scale=0.8), 
            # 'colsample_bytree': sp_uniform(loc=0.4, scale=0.6),
            # 'reg_alpha': [ 1, 2, 5, 7, 10, 50, 100],
            # 'reg_lambda': [ 1, 5, 10, 20, 50, 100]
             }

lgb_cv = GridSearchCV(estimator=model_lgb, 
                   param_grid=grid_params_lgb,
                   scoring='accuracy', 
                   verbose=1, cv=5)

# %%
lgb_cv.fit(X_train_res,y_train_res)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# GridSearchCV(cv=5,
#              estimator=LGBMClassifier(learning_rate=0.09, max_depth=-5,
#                                       random_state=42),
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'min_child_samples': [10, 20, 50, 100],
#                          'min_child_weight': [0.1, 1, 10.0],
#                          'n_estimators': [5, 10, 20], 'num_leaves': [6, 50]},
#              scoring='accuracy', verbose=1)

# %%
lgb_cv.best_params_
# Out:
# {'learning_rate': 0.1,
#  'min_child_samples': 10,
#  'min_child_weight': 10.0,
#  'n_estimators': 20,
#  'num_leaves': 50}

# %%
lgb_cv.best_score_
# Out:
# 0.9094369029208467

# %%
score['lightgbm']=  (np.mean(lgb_cv.best_score_) * 100).round(3)
score
# Out:
# {'adaboost': 83.696, 'xgboost': 86.387, 'lightgbm': 90.944}

# %% [markdown]
# The exhaustive search identified the best parameters for our xgboost Classifier to be learning_rate=0.1,min_child_samples=10, min_child_weight= 10,num_leaves = 50 and n_estimators=20. This combination of parameters produced an accuracy score of 0.9094369029208467.

# %% [markdown]
# #### Pros and Cons of lightGBM

# %% [markdown]
# 1)Pros
# - XGBoost is a very fast and accurate ML algorithm. LightGBM  is even faster. The key difference in speed is because XGBoost split the tree nodes one level at a time and LightGBM does that one node at a time.
# - Other advantages are low memory usage, high accuracy, parallel learning, corporate support, and scale-ability.
#
# 2)Cons
# - XGBoost has a feature that LightGBM lacks — monotonic constraint. It will sacrifice some model accuracy and increase training time, but may improve model interpretability.
# - Also there is very less community support.

# %% [markdown]
# ### 4. CatBoost Model

# %%
#pip install catboost

# %%
from catboost import CatBoostClassifier

model_cat = CatBoostClassifier(
    learning_rate=0.1 
    #n_estimators = int(n_estimators),
    #                        subsample = subsample, 
    #                        l2_leaf_reg = l2_leaf_reg,
    #                        max_depth = int(depth),
    #                        num_leaves = int(num_leaves),
    #                        random_state = 88,
    #                        grow_policy = "Lossguide",
    #                        max_bin = int(max_bin),  
    #                        use_best_model = True, 
    #                        model_size_reg = model_size_reg,
    
)
model_cat

# %%
model_cat.fit(X_train_res, y_train_res)
# Out:
# 0:	learn: 0.5900993	total: 186ms	remaining: 3m 5s
# 1:	learn: 0.5120597	total: 218ms	remaining: 1m 48s
# 2:	learn: 0.4672118	total: 250ms	remaining: 1m 23s
# 3:	learn: 0.4243167	total: 294ms	remaining: 1m 13s
# 4:	learn: 0.3936580	total: 325ms	remaining: 1m 4s
# 5:	learn: 0.3766468	total: 353ms	remaining: 58.5s
# 6:	learn: 0.3611433	total: 380ms	remaining: 53.8s
# 7:	learn: 0.3467670	total: 407ms	remaining: 50.5s
# 8:	learn: 0.3392876	total: 433ms	remaining: 47.7s
# 9:	learn: 0.3305153	total: 461ms	remaining: 45.6s
# 10:	learn: 0.3226632	total: 486ms	remaining: 43.7s
# 11:	learn: 0.3159623	total: 517ms	remaining: 42.6s
# 12:	learn: 0.3051788	total: 546ms	remaining: 41.4s
# 13:	learn: 0.2944864	total: 576ms	remaining: 40.6s
# 14:	learn: 0.2884991	total: 606ms	remaining: 39.8s
# 15:	learn: 0.2849815	total: 636ms	remaining: 39.1s
# 16:	learn: 0.2762931	total: 668ms	remaining: 38.6s
# 17:	learn: 0.2731782	total: 699ms	remaining: 38.1s
# 18:	learn: 0.2714457	total: 728ms	remaining: 37.6s
# ...

# %%
# make the predictions 
y_pred_cat_res=model_cat.predict(X_test)

# %%
#model Accuracy, how often is the classifier correct
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred_cat_res)
# Out:
# 0.9102465559037427

# %% [markdown]
# #### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
grid_param_cat={'n_estimators':[5, 10,20,30],
        'learning_rate': [0.03, 0.1],
        'depth': [2, 4, 6 ],  
        'l2_leaf_reg': [0.1, 0.5, 1]}


cat_cv = GridSearchCV(estimator=model_cat, 
                   param_grid=grid_param_cat,
                   scoring='accuracy', 
                   verbose=1, cv=5)

cat_cv
# Out:
# GridSearchCV(cv=5,
#              estimator=<catboost.core.CatBoostClassifier object at 0x0000028749624C70>,
#              param_grid={'depth': [2, 4, 6], 'l2_leaf_reg': [0.1, 0.5, 1],
#                          'learning_rate': [0.03, 0.1],
#                          'n_estimators': [5, 10, 20, 30]},
#              scoring='accuracy', verbose=1)

# %%
cat_cv.fit(X_train_res,y_train_res)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# 0:	learn: 0.6806034	total: 12ms	remaining: 48ms
# 1:	learn: 0.6687545	total: 22.5ms	remaining: 33.7ms
# 2:	learn: 0.6575794	total: 33.1ms	remaining: 22.1ms
# 3:	learn: 0.6469737	total: 44ms	remaining: 11ms
# 4:	learn: 0.6369531	total: 54.8ms	remaining: 0us
# 0:	learn: 0.6811513	total: 11.4ms	remaining: 45.6ms
# 1:	learn: 0.6697869	total: 22.1ms	remaining: 33.1ms
# 2:	learn: 0.6590743	total: 32.2ms	remaining: 21.5ms
# 3:	learn: 0.6489345	total: 43.2ms	remaining: 10.8ms
# 4:	learn: 0.6393397	total: 53.8ms	remaining: 0us
# 0:	learn: 0.6811390	total: 11.8ms	remaining: 47.1ms
# 1:	learn: 0.6697524	total: 22.1ms	remaining: 33.2ms
# 2:	learn: 0.6590440	total: 32.4ms	remaining: 21.6ms
# 3:	learn: 0.6488800	total: 43.2ms	remaining: 10.8ms
# 4:	learn: 0.6392894	total: 53.6ms	remaining: 0us
# 0:	learn: 0.6811365	total: 11.6ms	remaining: 46.4ms
# 1:	learn: 0.6697561	total: 22.1ms	remaining: 33.2ms
# ...

# %%
#returns the estimator with the best performance
cat_cv.best_estimator_

# %%
#returns the best score
cat_cv.best_score_
# Out:
# 0.8761163551214362

# %%
#returns the best parameters
cat_cv.best_params_
# Out:
# {'depth': 6, 'l2_leaf_reg': 1, 'learning_rate': 0.1, 'n_estimators': 30}

# %%
score['catboost']=  (np.mean(cat_cv.best_score_) * 100).round(3)
score
# Out:
# {'adaboost': 83.696, 'xgboost': 86.387, 'lightgbm': 90.944, 'catboost': 87.612}

# %% [markdown]
# The exhaustive search identified the best parameters for our catboost Classifier to be learning_rate=0.1,depth=6,
# l2_leaf_reg = 1 and n_estimators=30. This combination of parameters produced an accuracy score of 0.8761163551214362.

# %% [markdown]
# #### Pros and Cons of CatBoost

# %% [markdown]
# 1)Pros
# - No need to externally encode categorical variables.
# - It is said to be faster in implementation of GPU/CPU training.
# - Because it uses symmetric trees, that makes it to have a fast inference
# - Its boosting schemes helps to reduce over fitting and improves quality of the model
# - It supports sophisticated categorical features
# - It is easy to use and supports Python and R
#
# 2)Cons
# - High training and optimization times.

# %% [markdown]
# Since the accuracy value is highest for lightGBM after hypertuning(~91%), we will use LGBM to predict the probabilities for delinquency.

# %%
score_df = pd.DataFrame(list(score.items()), columns=['Algorithm', 'Score'])
score_df.head()
# Out:
#   Algorithm   Score
# 0  adaboost  83.696
# 1   xgboost  86.387
# 2  lightgbm  90.944
# 3  catboost  87.612

# %%
score_df.plot.bar(x="Algorithm", y='Score', rot=70, title="Score per Algorithm")
plt.show(block=True)

# %%
#return the raw probability that a sample is predicted to be in a class
lgbProbs = lgb_cv.predict_proba(X_test)
lgbDF = pd.DataFrame({'Probability': lgbProbs[:,1]})
lgbDF.to_csv('submission.csv', index=False)
lgbDF.head(2)
# Out:
#    Probability
# 0     0.249884
# 1     0.280146

# %% [markdown]
# ### Conclusion

# %% [markdown]
# This is a very basic overview of different types of boosting methods.  Amongst all the boosting algorithms that we experimented here, lightGBM gave the best performance.
